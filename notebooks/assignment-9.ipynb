# %% [markdown]
# # Assignment 9
# **Perform a bivariate analysis on the columns with numerical data in the penguins dataset:**
# - Use corr() on the DataFrame to calculate all the correlations. Use the code example above to show the correlation table with colors.
# - Look at the corrrelations. Do they match your expectations?
# - Show a scatter plot for:
#    - The strongest positive correlation
#    - The strongest negative correlation
#    - The weakest correlation
#
# ---

# %% [markdown]
# #### Assumption:
# Ik heb geen verwachtingen voor deze data omdat ik geen idee heb hoe penguins werken hier.

# %%
# Laad benodigdheden in voor de rest van dit bestand.
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
penguins = sns.load_dataset("penguins")
penguins = penguins.dropna()

# %%
# numeric columns
numeric_penguins = penguins.select_dtypes(include='number')
# Correlation
corr = numeric_penguins.corr()

# Display heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0, fmt='.2f', linewidths=0.5)
plt.title("Correlation of Penguin Numerical")
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Strongest positive correlation
sns.scatterplot(data=penguins, x='flipper_length_mm', y='body_mass_g', hue='species', ax=axes[0])
axes[0].set_title('Strongest Positive\nFlipper Length vs Body Mass')
axes[0].set_xlabel('Flipper Length (mm)')
axes[0].set_ylabel('Body Mass (g)')
axes[0].grid(True)

# Strongest negative correlation
sns.scatterplot(data=penguins, x='bill_depth_mm', y='flipper_length_mm', hue='species', ax=axes[1])
axes[1].set_title('Strongest Negative\nBill Depth vs Flipper Length')
axes[1].set_xlabel('Bill Depth (mm)')
axes[1].set_ylabel('Flipper Length (mm)')
axes[1].grid(True)

# Weakest correlation
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species', ax=axes[2])
axes[2].set_title('Weakest Correlation\nBill Length vs Bill Depth')
axes[2].set_xlabel('Bill Length (mm)')
axes[2].set_ylabel('Bill Depth (mm)')
axes[2].grid(True)

plt.tight_layout()
plt.show()
